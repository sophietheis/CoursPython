# %% [markdown]
# Charger le fichier positionNoyau.csv

# %%
import pandas as pd
filename = 'datas/positionNoyau.csv'
data = pd.read_csv(filename, sep=';', decimal=b',')

# %% [markdown]
# 1- Ajouter une colonne qui calcule la position normalisé du noyau (pos = apical/(apical+basal))
# 2- Afficher le boxplot en fonction de la colonne Condition, et en fonction des colonnes Condition et Apoptotic.
# 3- Modifier le rendu du boxplot
# 4- Faites les tests statistiques pour savoir s'il y a des différences significatives ou non.

# %%
data['normalized_position'] = data.Apical/(data.Apical+data.Basal)

# %%
data.boxplot(column='normalized_position', by=['Condition', 'Apoptotic'])

# %%
Test statistique.
